# %% [markdown]
# # Time-Frecuency
# *  Jose Gonzalez Lopez
# *  Mykola Lyashuha

# %% [markdown]
# # Introduction
# This is the intro

# %% [markdown]
# # Imports

# %%
#TO DO

# %% [markdown]
# # Auxiliar Functions

# %%
#TO DO

# %% [markdown]
# # Data

# %%
#TO DO

# %% [markdown]
# # Noisy versions

# %%
#TO DO

# %% [markdown]
# # Spectral Substraction

# %%
#TO DO

# %% [markdown]
# # Denoising

# %%
#TO DO

# %% [markdown]
# # Discussion parameters

# %% [markdown]
# DISCUSSION

# %% [markdown]
# # Conclusions

# %% [markdown]
# CONCLUSIONS
