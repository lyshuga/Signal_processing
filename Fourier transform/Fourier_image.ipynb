# %% [markdown]
# #ZOOM IN IMAGES
#
#
# *   Mykola Liashuha
# *   Jose Gonzalez Lopez

# %% [markdown]
# #INTRODUCTION
# This notebook will perform a spectral analysis of a photography with having the goal to make certain operations with the Fourier Transform. We will resize the image with a smaller scale in the space and Fourier domains and we will get a bigger scale using sinc and linea interpolation respectively. In the end we will draw our conclusions of the project.

# %% [markdown]
# #IMPORTS

# %%
import cv2 #Read images and do operations
import numpy as np #Operations
from matplotlib import pyplot as plt #Ploting
from scipy import fftpack
from matplotlib.colors import LogNorm # For the spectrum

# %% [markdown]
# #AUXILIAR FUNCTIONS

# %%
'''
Plots the spectrum of a fourier domain image
'''
def plot_spectrum(im_fft):
    # A logarithmic colormap
    plt.imshow(np.abs(im_fft), norm=LogNorm(vmin=5))
    plt.colorbar()

# %% [markdown]
# #THE DATA
# First we will start by opening the files and do a simple scan to see the main properties of the images that we are going to resize and study.

# %%
img = cv2.imread('barbara.jpg') #Reading
height,width,_ = img.shape

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %% [markdown]
# #SMALLER IMAGE
# ##FOURIER TRANSFORM
# Let's apply the Fourier Transform to the image after converting it to a greyscale image.

# %%
dark_image_grey_fourier = np.fft.fft2(gray) #Apply Fourier transform

plt.figure(num=None, figsize=(8, 6), dpi=80)
plt.imshow(np.log(abs(dark_image_grey_fourier)), cmap='gray'); #We want grey values
plt.show()

# %%
dark_image_grey_fourier = np.fft.fft2(gray)
dark_image_grey_fourier = np.fft.fftshift(dark_image_grey_fourier)

dark_image_grey_fourier = dark_image_grey_fourier[128:384, 128:384]





plt.figure(num=None, figsize=(8, 6), dpi=80)
plt.imshow(np.log(abs(dark_image_grey_fourier)), cmap='gray')

# %%
im_new = fftpack.ifft2(np.fft.ifftshift(dark_image_grey_fourier)).real

plt.figure()
plt.imshow(im_new, plt.cm.gray)
plt.title('Reconstructed Image')
# Out:
# Text(0.5, 1.0, 'Reconstructed Image')

# %%
im_new.shape
# Out:
# (256, 256)

# %%
points=(int(width/2), int(height/2)) #We prepare the points for the interpolation, double size
img_linear = cv2.resize(img, points, interpolation= cv2.INTER_LINEAR) #And resize with linear interpolation
plt.figure() #Plot
plt.imshow(img_linear)
plt.show()

# %% [markdown]
# ### Scale up

# %%
dark_image_grey_fourier = np.fft.fft2(gray)
dark_image_grey_fourier = np.fft.fftshift(dark_image_grey_fourier)

sample = np.zeros((1024, 1024), dtype=dark_image_grey_fourier.dtype)
sample[256:768, 256:768] = dark_image_grey_fourier
dark_image_grey_fourier = sample




plt.figure(num=None, figsize=(8, 6), dpi=80)
plt.imshow(np.log(abs(dark_image_grey_fourier)), cmap='gray')
# Out:
# /home/mykola/anaconda3/envs/nets/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log
#   if sys.path[0] == '':

# %%
im_new = fftpack.ifft2(np.fft.ifftshift(dark_image_grey_fourier)).real

plt.figure()
plt.imshow(im_new, plt.cm.gray)
plt.title('Reconstructed Image')
# Out:
# Text(0.5, 1.0, 'Reconstructed Image')

# %%
im_new.shape
# Out:
# (1024, 1024)

# %%
points=(2*width, 2*height) #We prepare the points for the interpolation, double size
img_linear = cv2.resize(img, points, interpolation= cv2.INTER_LINEAR) #And resize with linear interpolation
plt.figure() #Plot
plt.imshow(img_linear)
plt.show()

# %%
im_fft = fftpack.fft2(gray)

# Show the results, get the spectrum
plt.figure()
plot_spectrum(im_fft)
plt.title('Fourier transform')
# Out:
# Text(0.5, 1.0, 'Fourier transform')

# %%
# In the lines following, we'll make a copy of the original spectrum and
# truncate coefficients.

# Define the fraction of coefficients (in each direction) we keep
keep_fraction = 0.05

# Call ff a copy of the original transform. Numpy arrays have a copy
# method for this purpose.
im_fft2 = im_fft.copy()

# Set r and c to be the number of rows and columns of the array.
r, c = im_fft2.shape

# Set to zero all rows with indices between r*keep_fraction and
# r*(1-keep_fraction):
im_fft2[int(r*keep_fraction):int(r*(1-keep_fraction))] = 0

# Similarly with the columns:
im_fft2[:, int(c*keep_fraction):int(c*(1-keep_fraction))] = 0

plt.figure()
plot_spectrum(im_fft2)
plt.title('Filtered Spectrum')
# Out:
# Text(0.5, 1.0, 'Filtered Spectrum')

# %%
im_fft2
# Out:
# array([[ 2.91672640e+07      -0.j        ,
#         -7.62134157e+05-1438102.7968973j ,
#          2.63066161e+05+1530620.01152951j, ...,
#         -1.03724624e+05 +225592.10046859j,
#          2.63066161e+05-1530620.01152951j,
#         -7.62134157e+05+1438102.7968973j ],
#        [-9.20884103e+05-2352747.12712124j,
#         -2.18602622e+06+1125258.55433232j,
#          9.88319379e+03 -510177.90778459j, ...,
#         -4.00143140e+05 -456613.65583479j,
#          3.92102532e+05 +228905.24402621j,
#          7.94783653e+05  +15883.70285337j],
#        [-3.32072446e+05+1085627.72813743j,
#          2.57979527e+05+1231730.45128706j,
#          5.01473993e+05 +208083.20031722j, ...,
#          5.96479870e+04 -300641.65712684j,
#         -9.69159735e+05 +552171.15072326j,
#          1.87820090e+05 -179392.73996506j],
#        ...,
#        [-3.17749623e+05 -191861.17236273j,
#         -5.99869787e+05 -600098.36990487j,
#         -7.56861292e+04 +130418.65326241j, ...,
#         -8.22478746e+05 -534794.83563098j,
#         -2.69136481e+05  -12126.33269589j,
#         -1.61263983e+05 +419128.19902518j],
#        [-3.32072446e+05-1085627.72813743j,
#          1.87820090e+05 +179392.73996506j,
#         -9.69159735e+05 -552171.15072326j, ...,
#          6.83043603e+05 -138881.88551315j,
#          5.01473993e+05 -208083.20031722j,
#          2.57979527e+05-1231730.45128706j],
#        [-9.20884103e+05+2352747.12712124j,
#          7.94783653e+05  -15883.70285337j,
#          3.92102532e+05 -228905.24402621j, ...,
#          2.82124618e+05-1824353.83484794j,
#          9.88319379e+03 +510177.90778459j,
#         -2.18602622e+06-1125258.55433232j]])

# %%
im_new = fftpack.ifft2(im_fft2).real

plt.figure()
plt.imshow(im_new, plt.cm.gray)
plt.title('Reconstructed Image')
# Out:
# Text(0.5, 1.0, 'Reconstructed Image')

# %%
im_fft[256]
# Out:
# array([ 6.34400000e+03-0.00000000e+00j,  2.39331432e+03-4.19106032e+03j,
#        -9.54969630e+02-1.98697919e+02j, -1.40857276e+03-3.64425431e+03j,
#        -6.16074775e+02-3.82549077e+02j, -2.83864579e+02-1.31573031e+02j,
#        -6.59711910e+01+7.91916060e+02j,  9.22052714e+02+5.18328364e+02j,
#         5.30662843e+02+7.06802694e+02j, -7.56644972e+02+4.85059112e+02j,
#        -6.51328721e+02-4.35253214e+02j, -2.59847744e+02-3.32347052e+02j,
#         5.04116594e+02+3.58391494e+02j,  5.47258453e+02+1.81454860e+02j,
#         7.32832859e+02-5.55565146e+02j,  3.29456520e+02+1.11655963e+03j,
#        -4.79974613e+02-4.42488463e+02j,  1.21558431e+02+2.09792070e+01j,
#        -1.29113392e+02-2.17080320e+00j,  4.38754729e+02+3.54130094e+02j,
#        -4.35296680e+02-4.01991060e+02j,  8.94059513e+02-3.41620084e+02j,
#        -2.56663642e+02+6.31406738e+02j,  1.77295470e+02-2.37222189e+02j,
#        -5.73516871e+02+2.51716174e+02j, -3.48401199e+02-3.56152592e+02j,
#         8.19693457e+01-9.70563508e+02j,  4.31295435e+02+3.45724745e+02j,
#         1.74754134e+02+9.40156496e+01j,  6.00628092e+02+5.34383201e+02j,
#        -5.54775060e+02-3.67818341e+02j,  1.00748998e+03+4.58006415e+02j,
#         3.66376355e+02-2.17260357e+02j,  9.14977407e+02-3.16723020e+02j,
#         2.27740793e+01+7.87247169e+02j,  2.28504221e+02-6.92816926e+02j,
#        -1.81429923e+02+6.81498017e+02j, -1.05385635e+03-2.16711532e+02j,
#         7.14813825e+02+8.49932698e+02j, -7.14305794e+02-5.56236188e+02j,
#        -8.26912959e+02+4.83124171e+02j,  9.11651153e+01+5.79962023e+02j,
#        -7.81442186e+02-4.32438509e+02j,  1.16942173e+03+7.87001850e+02j,
#        -8.16904583e+02-3.27200725e+02j, -3.54137126e+01+5.01022635e+02j,
#        -1.46915048e+03-7.09835291e+02j, -2.13778442e+03+2.79254808e+03j,
#        -2.23131192e+03+9.86902352e+01j,  1.15113344e+02+2.05281040e+03j,
#        -7.82241565e+02+1.39677202e+03j, -2.49656776e+02+5.29903193e+02j,
#        -1.80634174e+03+1.48167773e+02j, -1.21945360e+02+9.82117562e+02j,
#         2.81471649e+03-1.11582206e+03j, -1.40857276e+03+3.64425431e+03j,
#        -9.54969630e+02+1.98697919e+02j,  2.39331432e+03+4.19106032e+03j])

# %%
plt.imshow(cv2.resize(gray, (256, 256)), cmap='gray')
plt.show()
im_fft = fftpack.fft2(gray)
# im_fft = cv2.resize(im_fft.astype('float32'), (256, 256))
# im_new = fftpack.ifft2(im_fft).real
# plt.imshow(cv2.resize(im_new, (256, 256)), cmap='gray')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: ComplexWarning: Casting complex values to real discards the imaginary part
#   after removing the cwd from sys.path.

# %% [markdown]
# #BIGGER IMAGE

# %% [markdown]
# ##SINC INTERPOLATION

# %%
#Code

# %% [markdown]
# ##LINEAR INTERPOLATION
# For the linear interpolation, we will just resize the image in the space domain and use the cv2 library to do the operations for us.

# %%
points=(2*width, 2*height) #We prepare the points for the interpolation, double size
img_linear = cv2.resize(img, points, interpolation= cv2.INTER_LINEAR) #And resize with linear interpolation
plt.figure() #Plot
plt.imshow(img_linear)
plt.show()

# %% [markdown]
# #CONCLUSIONS
